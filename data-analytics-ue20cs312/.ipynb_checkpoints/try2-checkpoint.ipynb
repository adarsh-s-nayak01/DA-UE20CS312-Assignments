# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
df = pd.read_csv('./train.csv',parse_dates=['Date'],index_col=['Date'])
df
# Out:
#                Open     High      Low    Close    Volume
# Date
# 2016-01-04  1099.59  1110.75  1093.85  1109.64  66545000
# 2016-01-05  1117.47  1130.57  1112.75  1125.85  41227200
# 2016-01-06  1116.63  1138.68  1116.10  1133.04  42316800
# 2016-01-07  1122.00  1149.76  1117.56  1143.37  64899600
# 2016-01-08  1145.64  1149.96  1120.93  1122.88  52138900
# ...             ...      ...      ...      ...       ...
# 2022-07-25  2412.25  2429.44  2387.41  2402.95  29106300
# 2022-07-26  2289.29  2307.08  2255.66  2280.27  48503400
# 2022-07-27  2309.14  2404.25  2296.82  2395.54  43790900
# 2022-07-28  2385.58  2443.26  2377.34  2434.89  25807000
# 2022-07-29  2410.86  2479.24  2406.35  2474.93  32907600
#
# [1655 rows x 5 columns]

# %%
#plot close price
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(df['Close'])
plt.title('closing price plot against time')
plt.show()

# %%
df_close = df['Close']
df_close.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
test_stationarity(df_close)
# Out:
# Results of dickey fuller test
# Test Statistics                  -0.961490
# p-value                           0.767050
# No. of lags used                  9.000000
# Number of observations used    1645.000000
# critical value (1%)              -3.434331
# critical value (5%)              -2.863299
# critical value (10%)             -2.567706
# dtype: float64

# %%
result = seasonal_decompose(df_close, model='multiplicative', period = 252)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(df_close)
moving_avg = df_close.rolling(12).mean()
std_dev = df_close.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend(loc="best")
plt.show()
test_stationarity(df_close)
# Out:
# No handles with labels found to put in legend.
# Results of dickey fuller test
# Test Statistics                  -0.961490
# p-value                           0.767050
# No. of lags used                  9.000000
# Number of observations used    1645.000000
# critical value (1%)              -3.434331
# critical value (5%)              -2.863299
# critical value (10%)             -2.567706
# dtype: float64

# %%
train_data, test_data = df_close[3:int(len(df_close)*0.9)], df_close[int(len(df_close)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(train_data, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=10, max_q=10, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=True,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=13088.059, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=13056.248, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=13058.735, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=13090.684, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=13056.955, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=13057.144, Time=0.23 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=13058.947, Time=0.28 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=13060.558, Time=0.03 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0] intercept
# Total fit time: 1.109 seconds
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 1486
# Model:               SARIMAX(1, 1, 0)   Log Likelihood               -6525.124
# Date:                Mon, 17 Oct 2022   AIC                          13056.248
# ...

# %%
import statsmodels.api as sm
model=sm.tsa.statespace.SARIMAX(df_close,order=(1, 1, 0))
results=model.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 1655
# Model:               SARIMAX(1, 1, 0)   Log Likelihood               -7482.391
# Date:                Mon, 17 Oct 2022   AIC                          14968.782
# Time:                        01:13:49   BIC                          14979.604
# Sample:                             0   HQIC                         14972.794
#                                - 1655
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0770      0.010     -7.531      0.000      -0.097      -0.057
# sigma2       497.7186      7.400     67.264      0.000     483.216     512.221
# ...
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              5882.21
# ...

# %%
model_autoARIMA.fit(train_data)
# print(train_data)
# print(test_data)
forecast = results.forecast(35)
true_forecast = forecast
print(forecast.count())
print(true_forecast.count())
# Out:
# 35
# 35
# C:\Users\Hp\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
ture_test['Close'] = list(true_forecast)
ture_test = ture_test.drop(['Open','High','Low','Volume'],axis=1)
# ture_test= ture_test.set_index('Date')

ture_test.to_csv('./submission.csv')
ture_test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6886331c412a> in <module>
# ----> 1 ture_test['Close'] = list(true_forecast)
#       2 ture_test = ture_test.drop(['Open','High','Low','Volume'],axis=1)
#       3 # ture_test= ture_test.set_index('Date')
#       4
#       5 ture_test.to_csv('./submission.csv')
#
# NameError: name 'ture_test' is not defined
